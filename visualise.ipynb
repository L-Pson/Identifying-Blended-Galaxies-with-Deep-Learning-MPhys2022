# %%
import visualkeras
from supportFunctions import createModel
from PIL import ImageFont

# %%
modelName = "tuned
model = createModel("tuned5", True)
font = ImageFont.truetype("arial.ttf", 32)  
visualkeras.layered_view(model, to_file='output.png', legend=True, font=font)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 126, 126, 128)     1280
#
#  max_pooling2d_20 (MaxPoolin  (None, 63, 63, 128)      0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 61, 61, 400)       461200
#
#  max_pooling2d_21 (MaxPoolin  (None, 30, 30, 400)      0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 224)       806624
#
#  max_pooling2d_22 (MaxPoolin  (None, 14, 14, 224)      0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 12, 12, 392)       790664
#
#  max_pooling2d_23 (MaxPoolin  (None, 6, 6, 392)        0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 4, 4, 104)         367016
#
#  max_pooling2d_24 (MaxPoolin  (None, 2, 2, 104)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 416)               0
#
#  dense_8 (Dense)             (None, 42)                17514
#
#  dense_9 (Dense)             (None, 1)                 43
#
# =================================================================
# Total params: 2,444,341
# Trainable params: 2,444,341
# Non-trainable params: 0
# _________________________________________________________________
# <PIL.Image.Image image mode=RGBA size=593x806 at 0x2A8E3EBE020>
